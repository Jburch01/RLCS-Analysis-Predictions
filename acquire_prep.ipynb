# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('main.csv')

# %%
df
# Out:
#                        event_id               event event_split event_region  \
# 0      614b7046f8090ec74528642d          Regional 1        Fall      Oceania
# 1      614b7046f8090ec74528642d          Regional 1        Fall      Oceania
# 2      614b7046f8090ec74528642d          Regional 1        Fall      Oceania
# 3      614b7046f8090ec74528642d          Regional 1        Fall      Oceania
# 4      614b7046f8090ec74528642d          Regional 1        Fall      Oceania
# ...                         ...                 ...         ...          ...
# 18735  614b6485f8090ec745286425  World Championship      Summer        World
# 18736  614b6485f8090ec745286425  World Championship      Summer        World
# 18737  614b6485f8090ec745286425  World Championship      Summer        World
# 18738  614b6485f8090ec745286425  World Championship      Summer        World
# 18739  614b6485f8090ec745286425  World Championship      Summer        World
#
# ...

# %%
df2 = pd.read_csv('games_by_teams.csv')

# %%
df2
# Out:
#                         game_id   color                   team_id  \
# 0      616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a
# 1      616004f3143c37878b238690  orange  614c8930f8090ec745286474
# 2      616004f7143c37878b238697    blue  6020bc8ef1e4807cc700391a
# 3      616004f7143c37878b238697  orange  614c8930f8090ec745286474
# 4      616004fc143c37878b23869e    blue  6020bc8ef1e4807cc700391a
# ...                         ...     ...                       ...
# 35589  62f99681da9d7ca1c7bb3536  orange  6020bc70f1e4807cc70023a5
# 35590  62f99825da9d7ca1c7bb353d    blue  6020bd98f1e4807cc700dc74
# 35591  62f99825da9d7ca1c7bb353d  orange  6020bc70f1e4807cc70023a5
# 35592  62f99ac9c437fde7e02daf25    blue  6020bd98f1e4807cc700dc74
# 35593  62f99ac9c437fde7e02daf25  orange  6020bc70f1e4807cc70023a5
#
#                                              team_slug           team_name  \
# 0      https://octane.gg/teams/391a-ground-zero-gaming  GROUND ZERO GAMING
# ...

# %%
df3 = pd.read_csv('matches_by_teams.csv')

# %%
df3
# Out:
#                        match_id   color                   team_id  \
# 0      6159ad3d143c37878b2384a9    blue  6020bc8ef1e4807cc700391a
# 1      6159ad3d143c37878b2384a9  orange  614c8930f8090ec745286474
# 2      6159ad3d143c37878b2384aa    blue  6020bc70f1e4807cc70023fb
# 3      6159ad3d143c37878b2384aa  orange  6156d4db143c37878b238367
# 4      6159ad3d143c37878b2384ab    blue  6020bc8ef1e4807cc7003915
# ...                         ...     ...                       ...
# 10589  62e02371da9d7ca1c7bb2f61  orange  6020bd98f1e4807cc700dc74
# 10590  62e02371da9d7ca1c7bb2f62    blue  6020bc70f1e4807cc70023a5
# 10591  62e02371da9d7ca1c7bb2f62  orange  605aca6853a71a78eacbc155
# 10592  62e02371da9d7ca1c7bb2f63    blue  6020bd98f1e4807cc700dc74
# 10593  62e02371da9d7ca1c7bb2f63  orange  6020bc70f1e4807cc70023a5
#
#                                              team_slug           team_name  \
# 0      https://octane.gg/teams/391a-ground-zero-gaming  GROUND ZERO GAMING
# ...
